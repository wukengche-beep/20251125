# %% [markdown]
# <a href="https://colab.research.google.com/github/wukengche-beep/20251125/blob/main/taipei20251125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 這是一個BMI 算法  體重(KG) / 身高 (M) ^2
weight = float(input("請輸入體重"))
height = float(input("請輸入身高"))
bmi = weight / (height / 100) ** 2

print("你輸入的體重是:" + str(weight))
print("你輸入的身高是:" + str(height))
print("計算出的BMI是:" + str(bmi))

# 縮排: tab
# 過濾型的單選題: 嚴格放上面
if bmi >= 25:
    print ("over")
elif bmi >= 18:
    print ("normal")
else:
    print("under")

print("!!!!")
# Out:
# 請輸入體重75
# 請輸入身高160
# 你輸入的體重是:75.0
# 你輸入的身高是:160.0
# 計算出的BMI是:29.296874999999993
# over
# !!!!

# %% [markdown]
# ```
# 1. 註解 #
# 2. 功能: print(參數) 就算功能不需要參數，() 還是要加
# 3. !!!!不要重複寫: 定義一次( 函式定義/物件導向)
# 4. =:
#   a. 5==3+2 (相等)
#   b. x=2 (帶入，是)
# 5. !!! 型態(分類)
#   a. 數字: 整數(3)(int) 小數(3.0)(float) 字串str()
#   b. 字串(str):"hhhhh" 字 : 中文/ 英文/ 標點/ 數字符號/ 空白建/
# 6. !!!! 型態轉換 int() float() str()
# 7. 功能有參數 / 回傳值 (做完這功能得到的 新的答案)  不是在原答案去執行
#
#
#
# ```

# %% [markdown]
# markdown 語法
# latex math
#
# $  \frac{1}{4} \pi r^2  $
